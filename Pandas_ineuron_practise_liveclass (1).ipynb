# %%
#30th july class

# %%
DATASET USED:

https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing

https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Sharanya\Downloads\sales_data_final.csv")
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#To list out all the columns
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['discount']#fetching one columns
# Out:
# 0        0.0
# 1        0.1
# 2        0.0
# 3        0.5
# 4        0.1
#         ...
# 51285    0.2
# 51286    0.0
# 51287    0.0
# 51288    0.0
# 51289    0.2
# Name: discount, Length: 51290, dtype: float64

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
#how to fetch 2 columns or more columns same time
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# ...         ...   ...
# 51285    4.5188  2014
# 51286    0.4200  2014
# 51287   12.3600  2014
# 51288    0.5600  2014
# 51289   -0.6048  2014
#
# [51290 rows x 2 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
#filter out column contains datatype==object
df.dtypes=='object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']#filtering out only datatypes having object
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
#fetching object dataset-index specifically usefor selecting rows and columns-Passing List int the dataframe gives us the data with specific columns
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.dtypes[df.dtypes=='float64'].index
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='float64'].index]#fetching dataframe for float datatype
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df['order_id'][1:40:2] #slicing operation
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
#creating a new column
df["new_col"]="sara"

# %%
df1=pd.read_excel(r"C:\Users\Sharanya\Downloads\Dress Sales.xlsx")

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.isnull()#checking the null values
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0       False      False      False                False                False
# 1       False      False      False                False                False
# 2       False      False      False                False                False
# 3       False      False      False                False                False
# 4       False      False      False                False                False
# ..        ...        ...        ...                  ...                  ...
# 495     False      False      False                False                False
# 496     False      False      False                False                False
# 497     False      False      False                False                False
# 498     False      False      False                False                False
# 499     False      False      False                False                False
#
# ...

# %%
df1.isnull().sum()##No Null Data present in the column
# Out:
# Dress_ID                 0
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64

# %%
#checking the customer_name has the profit values
df[df['profit']==max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df['country']=='Sweden']#fetching dataframe having country as sweden
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
len(df[df['country']=='Sweden'])#How many from sweden country
# Out:
# 203

# %%
df[df['shipping_cost']>20]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# ...                ...         ...         ...             ...
# 51241  ES-2014-3638865  12/31/2014    1/1/2015     First Class
# 51242   MX-2014-141712  12/31/2014  12/31/2014        Same Day
# 51243    IN-2014-78627  12/31/2014    1/4/2015  Standard Class
# 51244  IT-2014-3715679  12/31/2014    1/5/2015    Second Class
# 51245    IN-2014-75603  12/31/2014    1/5/2015    Second Class
#
#           customer_name      segment            state         country  market  \
# 0       Toby Braunhardt     Consumer      Constantine         Algeria  Africa
# ...

# %%
df[df['shipping_cost']>=20]['country']
# Out:
# 0               Algeria
# 6                Canada
# 7             Australia
# 8           New Zealand
# 9                  Iraq
#               ...
# 51241    United Kingdom
# 51242         Nicaragua
# 51243             China
# 51244       Netherlands
# 51245             India
# Name: country, Length: 14850, dtype: object

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)]#no and is allowed
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df[['profit','customer_name']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# dtype: object

# %%
#Converting into Date type Format
pd.to_datetime(df['order_date'])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
#data,day,time-operation
date = pd.to_datetime(df['order_date'])
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#Extracting only year from the date
df['order_date_year'] = df['converted_order_date'].dt.year
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#Extracting only month from the date
df['order_date_month'] = df['converted_order_date'].dt.month
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#Extracting week of the year from the date
df['order_date_week'] = df['converted_order_date'].dt.week
df
# Out:
# C:\Users\Sharanya\AppData\Local\Temp\ipykernel_13304\3127015009.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week'] = df['converted_order_date'].dt.week
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# ...

# %%
#In which month, we are going to do most sales --> Group by operation on month and then count
#In Pandas, this is equivalent to value_counts function
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.groupby(['order_date_month'])['order_date_month'].count()
# Out:
# order_date_month
# 1     2599
# 2     2168
# 3     3035
# 4     3057
# 5     3747
# 6     5331
# 7     3166
# 8     5078
# 9     5975
# 10    4490
# 11    6342
# 12    6302
# Name: order_date_month, dtype: int64

# %%
df['cost_to_company']=df['discount']+df['shipping_cost']
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# ...

# %%
df['cost_to_company'].max()
# Out:
# 933.57

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop(1) #Delete row 1 with index. Still we have 1st row when we display df
df

# %%
df.drop(1,inplace=True)

# %%
df.loc[[2,4]]#for extracting rows
# Out:
#         order_id order_date ship_date       ship_mode  customer_name  \
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 4  IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
#
#     segment            state    country market   region  ... sales quantity  \
# 2  Consumer         Budapest    Hungary   EMEA     EMEA  ...    66        4
# 4  Consumer  New South Wales  Australia   APAC  Oceania  ...   114        5
#
#   discount profit shipping_cost  order_priority  converted_order_date  \
# 2      0.0  29.64          8.17            High            2011-01-01
# 4      0.1  37.77          4.70          Medium            2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 4             2011                 1              52
#
# [2 rows x 24 columns]

# %%
df.loc[2:8]
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day      Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
#
#        segment            state      country  market   region  ...  \
# 2     Consumer         Budapest      Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm       Sweden      EU    North  ...
# 4     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 5     Consumer  New South Wales    Australia    APAC  Oceania  ...
# ...

# %%
df.loc[0:4,['order_id','order_date','ship_date']]##Extracting certain row and column
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4,0:3]#iloc understand default index ,it takes string of the column as a index
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011

# %%
df.iloc[2:6,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
#Performing Filter Options
df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')]  # | this is called as or
# Out:
# quantity              int64
# discount            float64
# profit              float64
# shipping_cost       float64
# order_date_year       int64
# order_date_month      int64
# order_date_week       int64
# dtype: object

# %%
df[df.dtypes[(df.dtypes=='float64') | (df.dtypes=='int64')].index]
# Out:
#        quantity  discount    profit  shipping_cost  year  cost_to_company
# 0             2       0.0  106.1400          35.46  2011            35.46
# 1             3       0.1   36.0360           9.72  2011             9.82
# 2             4       0.0   29.6400           8.17  2011             8.17
# 3             3       0.5  -26.0550           4.82  2011             5.32
# 4             5       0.1   37.7700           4.70  2011             4.80
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             1.09
# 51286         1       0.0    0.4200           0.49  2014             0.49
# 51287         3       0.0   12.3600           0.35  2014             0.35
# 51288         1       0.0    0.5600           0.20  2014             0.20
# 51289         3       0.2   -0.6048           0.17  2014             0.37
#
# [51290 rows x 6 columns]

# %%
df2 = df[df.dtypes[(df.dtypes == 'float64' )| (df.dtypes == 'int64')].index]
df2
# Out:
#        quantity  discount    profit  shipping_cost  order_date_year  \
# 0             2       0.0  106.1400          35.46             2011
# 2             4       0.0   29.6400           8.17             2011
# 3             3       0.5  -26.0550           4.82             2011
# 4             5       0.1   37.7700           4.70             2011
# 5             2       0.1   15.3420           1.80             2011
# ...         ...       ...       ...            ...              ...
# 51285         2       0.2    4.5188           0.89             2014
# 51286         1       0.0    0.4200           0.49             2014
# 51287         3       0.0   12.3600           0.35             2014
# 51288         1       0.0    0.5600           0.20             2014
# 51289         3       0.2   -0.6048           0.17             2014
#
#        order_date_month  order_date_week
# 0                     1               52
# 2                     1               52
# ...

# %%
df2[df2>100]
# Out:
#        quantity  discount  profit  shipping_cost  order_date_year  \
# 0           NaN       NaN  106.14            NaN             2011
# 2           NaN       NaN     NaN            NaN             2011
# 3           NaN       NaN     NaN            NaN             2011
# 4           NaN       NaN     NaN            NaN             2011
# 5           NaN       NaN     NaN            NaN             2011
# ...         ...       ...     ...            ...              ...
# 51285       NaN       NaN     NaN            NaN             2014
# 51286       NaN       NaN     NaN            NaN             2014
# 51287       NaN       NaN     NaN            NaN             2014
# 51288       NaN       NaN     NaN            NaN             2014
# 51289       NaN       NaN     NaN            NaN             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# ...

# %%
df3 = df2[df2 >100]

# %%
#Will drop if there is a single NA value in a row
df3.dropna() #If we want permanent delete then inplace = True needs to be used
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3.dropna(thresh=5) #Require that many non NAN values to not delete that row
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
#Filling NAN values with 4
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  order_date_year  \
# 0           4.0       4.0  106.14            4.0             2011
# 2           4.0       4.0    4.00            4.0             2011
# 3           4.0       4.0    4.00            4.0             2011
# 4           4.0       4.0    4.00            4.0             2011
# 5           4.0       4.0    4.00            4.0             2011
# ...         ...       ...     ...            ...              ...
# 51285       4.0       4.0    4.00            4.0             2014
# 51286       4.0       4.0    4.00            4.0             2014
# 51287       4.0       4.0    4.00            4.0             2014
# 51288       4.0       4.0    4.00            4.0             2014
# 51289       4.0       4.0    4.00            4.0             2014
#
#        order_date_month  order_date_week
# 0                   4.0              4.0
# 2                   4.0              4.0
# 3                   4.0              4.0
# ...

# %%
df3.fillna(value = df3['profit']).mean()
# Out:
# quantity                    NaN
# discount                    NaN
# profit               285.710477
# shipping_cost        205.753790
# order_date_year     2012.777243
# order_date_month            NaN
# order_date_week             NaN
# dtype: float64

# %%
(df3['profit']).mean()
# Out:
# 285.71047695983293

# %%
#Average profit yearwise
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
#Average Sales year wise
df['sales'] = df.sales.str.replace(',',"").astype(int) #Converting into integer
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64
